# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('https://raw.githubusercontent.com/BrijeshYadav001st/HighRadius-csv-file-/main/H2HBABBA1492.csv')

# %%
#Understnding the data

# %%
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
#To check the data size and length
data.tail()
# Out:
#       business_code cust_number   name_customer           clear_date  \
# 49995          U001  0200769623        WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878  SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557        BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463       KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720  DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# 49995         2020.0  1.930357e+09   2020-01-07           2020-01-05
# 49996         2019.0  1.929009e+09   2019-03-24           2019-03-22
# 49997         2019.0  1.928940e+09   2019-03-12           2019-03-12
# 49998         2019.0  1.929669e+09   2019-07-30           2019-07-27
# 49999         2019.0  1.930046e+09   2019-10-23           2019-10-23
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# ...

# %%
#read the header file
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'clear_date',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'invoice_currency',
#        'document type', 'total_open_amount', 'baseline_create_date',
#        'cust_payment_terms', 'invoice_id', 'isOpen'],
#       dtype='object')

# %%
#read each rows
print (data.head())
# Out:
#   business_code cust_number     name_customer           clear_date  \
# 0          CA02  0140105678   SAPUTO  systems                  NaN
# 1          U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2          U001  0200769623   WAL-MAR systems                  NaN
# 3          U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4          U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
#
#    buisness_year        doc_id posting_date document_create_date  \
# 0         2020.0  2.960620e+09   2020-03-10           2020-03-10
# 1         2019.0  1.929516e+09   2019-06-18           2019-06-19
# 2         2020.0  1.930689e+09   2020-03-24           2020-03-23
# 3         2019.0  1.928996e+09   2019-03-20           2019-03-20
# 4         2019.0  1.929976e+09   2019-10-08           2019-10-07
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200310   20200329.0              CAD            RV
# ...

# %%
# For unique value
data.nunique()
# Out:
# business_code                 5
# cust_number                1409
# name_customer              4177
# clear_date                  401
# buisness_year                 2
# doc_id                    48853
# posting_date                504
# document_create_date        504
# document_create_date.1      505
# due_in_date                 548
# invoice_currency              2
# document type                 2
# posting_id                    1
# area_business                 0
# total_open_amount         44306
# baseline_create_date        510
# cust_payment_terms           76
# invoice_id                48847
# isOpen                        2
# dtype: int64

# %%
# Droping waste and deplicate rows and columns
data.drop('area_business' ,axis=1 , inplace=True)
data.head(4999)
# Out:
#      business_code cust_number       name_customer           clear_date  \
# 0             CA02  0140105678     SAPUTO  systems                  NaN
# 1             U001  0200750051    ALBER foundation  2019-07-03 00:00:00
# 2             U001  0200769623     WAL-MAR systems                  NaN
# 3             U001  0200416837         DEC systems  2019-03-25 00:00:00
# 4             U001      CCCA02           KRAFT  co  2019-11-27 00:00:00
# ...            ...         ...                 ...                  ...
# 4994          U001  0200761734  H E BUT foundation                  NaN
# 4995          U001  0200974851           RESTA llc  2019-04-03 00:00:00
# 4996          U001  0200769623       WAL-MAR trust  2019-08-20 00:00:00
# 4997          CA02  0140104277         WALLA trust  2019-12-27 00:00:00
# 4998          U001  0200704858           WAKE corp  2019-04-29 00:00:00
#
#       buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
## Droping waste and deplicate rows and columns
data.drop('posting_id' ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
#Conversation of date in proper formate 

#data.clear_date.str.slice().astype('int').head()

data['posting_date']=pd.to_datetime(data['posting_date']).dt.normalize()
data['document_create_date']=pd.to_datetime(data['document_create_date'],format='%Y%m%d')
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
# Conversation invoice_currency in proper Formate

#data.invoice_currency.str.replace('USD','').astype('float').head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-77ca5be47dfc> in <module>
#       1 # Conversation invoice_currency in proper Formate
# ----> 2 data.invoice_currency.str.replace('USD','').astype('float').head()
#
# ~/work/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/work/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
#For Sorted Values
data.sort_values
# Out:
# <bound method DataFrame.sort_values of       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
data.set_index
# Out:
# <bound method DataFrame.set_index of       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
#Data Reset
data.reset_index
# Out:
# <bound method DataFrame.reset_index of       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
# For Null Values
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
#For dropping missing data (corelation... )
data.shape
# Out:
# (50000, 17)

# %%
##For dropping missing data (corelation... )
data.dropna()
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
###For dropping missing data (corelation... )
data.dropna(how='all').shape
# Out:
# (50000, 17)

# %%
###For dropping missing data (corelation... )remove waste rows f
data.dropna(axis=0)
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date document_create_date  \
# ...

# %%
#Check NA values in Rows
data.dropna(subset=['due_in_date','clear_date']).shape
# Out:
# (40000, 17)

# %%
#Invoc the Data (interpolate) without using Date .......

# %%
#Create a new data set

# %%
#Drop The NA values

# %%
#find Delay date 
#Delay Date = clear date - due date

# %%
#split the data set

# %%
data.corr()
# Out:
#                         buisness_year    doc_id  document_create_date  \
# buisness_year                1.000000 -0.012043              0.979740
# doc_id                      -0.012043  1.000000             -0.008226
# document_create_date         0.979740 -0.008226              1.000000
# document_create_date.1       0.984997 -0.010909              0.993956
# due_in_date                  0.989955 -0.014132              0.976334
# total_open_amount           -0.007710  0.169856             -0.004731
# baseline_create_date         0.985240 -0.009249              0.993405
# invoice_id                  -0.010395  1.000000             -0.006275
# isOpen                       0.754944 -0.011499              0.762992
#
#                         document_create_date.1  due_in_date  \
# buisness_year                         0.984997     0.989955
# doc_id                               -0.010909    -0.014132
# document_create_date                  0.993956     0.976334
# ...

# %%
data.iloc[]
